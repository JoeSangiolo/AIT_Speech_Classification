# %% [markdown]
# <a href="https://colab.research.google.com/github/bheinri2/DL_Speech_Recognition/blob/main/Speech_To_Text_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Trying to Use LibriSpeech Dataset ###

# %%
# !pip install audio2numpy

# %%
# !wget https://openslr.elda.org/resources/12/train-clean-100.tar.gz
# Out:
# --2022-03-06 20:12:07--  https://openslr.elda.org/resources/12/train-clean-100.tar.gz
# Resolving openslr.elda.org (openslr.elda.org)... 141.94.109.138, 2001:41d0:203:ad8a::
# Connecting to openslr.elda.org (openslr.elda.org)|141.94.109.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6387309499 (5.9G) [application/x-gzip]
# Saving to: ‘train-clean-100.tar.gz’
#
# train-clean-100.tar 100%[===================>]   5.95G  97.4MB/s    in 64s
#
# 2022-03-06 20:13:11 (95.8 MB/s) - ‘train-clean-100.tar.gz’ saved [6387309499/6387309499]

# %%
# !tar -xvzf "train-clean-100.tar.gz" -C "samples"
# Out:
# Streaming output truncated to the last 5000 lines.
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0035.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0027.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0031.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0011.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0029.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0005.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0004.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0023.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0010.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0020.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0014.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0032.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0016.flac
# LibriSpeech/train-clean-100/1263/141777/1263-141777-0015.flac
# ...

# %%
import torch
import torchaudio

# %%
sample_file = "samples/LibriSpeech/train-clean-100/1069/133699/1069-133699-0001.flac"
metadata = torchaudio.info(sample_file)
print(metadata)
# Out:
# AudioMetaData(sample_rate=16000, num_frames=253840, num_channels=1, bits_per_sample=16, encoding=FLAC)

# %% [markdown]
# ### Listening to an audio sample from LibriSpeech ###

# %%
import IPython as ip
ip.display.Audio(sample_file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Smaller test w/ single file ###

# %%
# !wget https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3
# Out:
# --2022-03-06 16:56:51--  https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3
# Resolving file-examples-com.github.io (file-examples-com.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to file-examples-com.github.io (file-examples-com.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 764176 (746K) [audio/mp3]
# Saving to: ‘file_example_MP3_700KB.mp3’
#
# file_example_MP3_70 100%[===================>] 746.27K  --.-KB/s    in 0.03s
#
# 2022-03-06 16:56:51 (23.2 MB/s) - ‘file_example_MP3_700KB.mp3’ saved [764176/764176]

# %%
from audio2numpy import open_audio
fp = "file_example_MP3_700KB.mp3"  # change to the correct path to your file accordingly
signal, sampling_rate = open_audio(fp)

# %%
pip install pydub

# %% [markdown]
# ### Back to LibriSpeech ###

# %%
#from audio2numpy import open_audio
from pydub import AudioSegment
flac_audio = AudioSegment.from_file("LibriSpeech/train-clean-100/4640/19187/4640-19187-0000.flac", "flac")
flac_audio.export("sampleMp3.mp3", format="mp3")


fp_test = "sampleMp3.mp3"  # change to the correct path to your file accordingly
signal, sampling_rate = open_audio(fp_test)

# %% [markdown]
# ### VoxCeleb Dataset ###

# %%
# installing dependencies
# !pip install -r requirements.txt

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/voxceleb/data/vox1_dev_txt.zip
# Out:
# --2022-03-06 17:18:00--  https://www.robots.ox.ac.uk/~vgg/data/voxceleb/data/vox1_dev_txt.zip
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139078084 (133M) [application/zip]
# Saving to: ‘vox1_dev_txt.zip’
#
# vox1_dev_txt.zip    100%[===================>] 132.63M  17.6MB/s    in 8.3s
#
# 2022-03-06 17:18:09 (16.0 MB/s) - ‘vox1_dev_txt.zip’ saved [139078084/139078084]

# %%
# !unzip vox1_dev_txt.zip /content/vox1_dev_txt/
# Out:
# Archive:  vox1_dev_txt.zip
# caution: filename not matched:  /content/vox1_dev_txt/
